# %%
pip install mysql_connector_python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd

# %%
try:
    mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "ahsanjaved@96",
    database = "nutrition_facts"
    )
    print("connected")
except:
    print("not connected")
# Out:
# connected

# %%
mycursor = mydb.cursor()

# %%
data = "(select * from mcdonald )"

# %%
mycursor.execute(data)

# %%
result  = mycursor.fetchall()

# %%
for i in result:
    print(i)
# Out:
# ('Breakfast', 'Egg McMuffin', '4.8 oz (136 g)', 300, 120, 13, 20, 5, 25, 0, 260, 87, 750, 31, 31, 10, 4, 17, 3, 17, 10, 0, 25, 15)
# ('Breakfast', 'Egg White Delight', '4.8 oz (135 g)', 250, 70, 8, 12, 3, 15, 0, 25, 8, 770, 32, 30, 10, 4, 17, 3, 18, 6, 0, 25, 8)
# ('Breakfast', 'Sausage McMuffin', '3.9 oz (111 g)', 370, 200, 23, 35, 8, 42, 0, 45, 15, 780, 33, 29, 10, 4, 17, 2, 14, 8, 0, 25, 10)
# ('Breakfast', 'Sausage McMuffin with Egg', '5.7 oz (161 g)', 450, 250, 28, 43, 10, 52, 0, 285, 95, 860, 36, 30, 10, 4, 17, 2, 21, 15, 0, 30, 15)
# ('Breakfast', 'Sausage McMuffin with Egg Whites', '5.7 oz (161 g)', 400, 210, 23, 35, 8, 42, 0, 50, 16, 880, 37, 30, 10, 4, 17, 2, 21, 6, 0, 25, 10)
# ('Breakfast', 'Steak & Egg McMuffin', '6.5 oz (185 g)', 430, 210, 23, 36, 9, 46, 1, 300, 100, 960, 40, 31, 10, 4, 18, 3, 26, 15, 2, 30, 20)
# ...

# %%
df = pd.read_sql_query(data,mydb)
# Out:
# C:\Users\ahsan\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# **to find mean,max,min,std,20% etc use describe**

# %%
df.describe(include = "all")
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
df.loc[12]
# Out:
# Category                                                          Breakfast
# Item                             Sausage Biscuit with Egg (Regular Biscuit)
# Serving Size                                                 5.7 oz (163 g)
# Calories                                                                510
# Calories from Fat                                                       290
# Total Fat                                                                33
# Total Fat (% Daily Value)                                                50
# Saturated Fat                                                            14
# Saturated Fat (% Daily Value)                                            71
# Trans Fat                                                                 0
# Cholesterol                                                             250
# Cholesterol (% Daily Value)                                              83
# ...

# %% [markdown]
# **lets do some analysis and visualization on this table**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# **first we need to analyze which food has so much sodium content**

# %%
plot = sns.swarmplot(x = "Category",y = "Sodium", data = df)
plt.setp(plot.get_xticklabels(),rotation = 70)
plt.title = "sodium content"
plt.show()
# Out:
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 63.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df["Sodium"].describe()
# Out:
# count     260.000000
# mean      495.750000
# std       577.026323
# min         0.000000
# 25%       107.500000
# 50%       190.000000
# 75%       865.000000
# max      3600.000000
# Name: Sodium, dtype: float64

# %% [markdown]
# **to return maximum index value**

# %%
df["Sodium"].idxmax()
# Out:
# 82

# %%
df.iloc[3]
# Out:
# Category                                         Breakfast
# Item                             Sausage McMuffin with Egg
# Serving Size                                5.7 oz (161 g)
# Calories                                               450
# Calories from Fat                                      250
# Total Fat                                               28
# Total Fat (% Daily Value)                               43
# Saturated Fat                                           10
# Saturated Fat (% Daily Value)                           52
# Trans Fat                                                0
# Cholesterol                                            285
# Cholesterol (% Daily Value)                             95
# Sodium                                                 860
# Sodium (% Daily Value)                                  36
# Carbohydrates                                           30
# Carbohydrates (% Daily Value)                           10
# ...

# %%
df.iloc[82]
# Out:
# Category                                       Chicken & Fish
# Item                             Chicken McNuggets (40 piece)
# Serving Size                                  22.8 oz (646 g)
# Calories                                                 1880
# Calories from Fat                                        1060
# Total Fat                                                 118
# Total Fat (% Daily Value)                                 182
# Saturated Fat                                              20
# Saturated Fat (% Daily Value)                             101
# Trans Fat                                                   1
# Cholesterol                                               265
# Cholesterol (% Daily Value)                                89
# Sodium                                                   3600
# Sodium (% Daily Value)                                    150
# Carbohydrates                                             118
# ...

# %%
df.at[82,"Item"]
# Out:
# 'Chicken McNuggets (40 piece)'

# %% [markdown]
# **to find the relation ship between protien and fat by making a joinplot**

# %%
plot = sns.jointplot(x = "Protein" ,y = "Total Fat", data = df)
plt.show()

# %%
df["Total Fat"].idxmax()
# Out:
# 82

# %%
df["Protein"].idxmax()
# Out:
# 82

# %%
df.at[82, "Item"]
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df["Sugars"].idxmax()
# Out:
# 253

# %%
df.at[253,"Item"]
# Out:
# 'McFlurry with M&Mâ€™s Candies (Medium)'

# %%
plot = sns.swarmplot(x = "Category",y = "Sugars", data = df)
plt.setp(plot.get_xticklabels(),rotation = 70)
plt.title = "suga content"
plt.show()
# Out:
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahsan\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df["Sugars"].idxmax()
# Out:
# 253

# %%
df.at[253,"Item"]
# Out:
# 'McFlurry with M&Mâ€™s Candies (Medium)'

# %%
df.iloc[253]
# Out:
# Category                                             Smoothies & Shakes
# Item                             McFlurry with M&Mâ€™s Candies (Medium)
# Serving Size                                            16.2 oz (460 g)
# Calories                                                            930
# Calories from Fat                                                   290
# Total Fat                                                            33
# Total Fat (% Daily Value)                                            50
# Saturated Fat                                                        20
# Saturated Fat (% Daily Value)                                       102
# Trans Fat                                                             1
# Cholesterol                                                          75
# Cholesterol (% Daily Value)                                          25
# Sodium                                                              260
# ...

# %% [markdown]
# **now find the sugar content bu using boxplot**

# %%
plot = sns.set_style("whitegrid")
ax = sns.boxplot(x = df["Sugars"])
plt.show()
